# %%
from network import Network
from importlib import reload
import simulation
reload(simulation)
from simulation import Simulation

from car import Car
from utils import read_txt_files, save_schedule, plot_validation_results, plot_best_validation_results

machine_positions, transport_demand = read_txt_files()

# %% [markdown]
# # Greedy Heuristic

# %% [markdown]
# ## 1 Car

# %%
network = Network(machine_positions, transport_demand)
car1 = Car(car_id=1, position=1)
cars = [car1]
simulation = Simulation(network, cars, schedule_name="greedy_heuristic/schedule_1_GH_k1.txt", k=1)
simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# greedy_heuristic/schedule_1_GH_k1.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/greedy_heuristic/schedule_1_GH_k1.txt

# %% [markdown]
# ## 5 Cars

# %%
network = Network(machine_positions, transport_demand)
cars = [Car(car_id=i, position=i) for i in range(1, 6)]
simulation = Simulation(network, cars, schedule_name="greedy_heuristic/schedule_5_GH_k1.txt", k=1)
simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# greedy_heuristic/schedule_5_GH_k1.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/greedy_heuristic/schedule_5_GH_k1.txt

# %% [markdown]
# ## 10 Cars

# %%
network = Network(machine_positions, transport_demand)
cars = [Car(car_id=i, position=i) for i in range(1, 11)]
simulation = Simulation(network, cars, schedule_name="greedy_heuristic/schedule_10_GH_k1.txt", k=1)
simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# greedy_heuristic/schedule_10_GH_k1.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/greedy_heuristic/schedule_10_GH_k1.txt

# %% [markdown]
# # Randomized Greedy Heuristic (random seed = 30)

# %% [markdown]
# ## 1 Car

# %%
for i in range(2, 11):
  network = Network(machine_positions, transport_demand)
  car1 = Car(car_id=1, position=1)
  cars = [car1]
  simulation = Simulation(network, cars, schedule_name=f"randomized_greedy_heuristic/schedule_1_RGH_k{i}.txt", k=i)
  simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_1_RGH_k2.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_1_RGH_k2.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_1_RGH_k3.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_1_RGH_k3.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_1_RGH_k4.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_1_RGH_k4.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_1_RGH_k5.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_1_RGH_k5.txt
# Starte Simulation...
# Simulation beendet.
# ...

# %% [markdown]
# ## 5 Cars

# %%
for i in range(2, 11):
  network = Network(machine_positions, transport_demand)
  cars = [Car(car_id=i, position=i) for i in range(1, 6)]
  simulation = Simulation(network, cars, schedule_name=f"randomized_greedy_heuristic/schedule_5_RGH_k{i}.txt", k=i)
  simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_5_RGH_k2.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_5_RGH_k2.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_5_RGH_k3.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_5_RGH_k3.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_5_RGH_k4.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_5_RGH_k4.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_5_RGH_k5.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_5_RGH_k5.txt
# Starte Simulation...
# Simulation beendet.
# ...

# %% [markdown]
# ## 10 Cars

# %%
for i in range(2, 11):
  network = Network(machine_positions, transport_demand)
  cars = [Car(car_id=i, position=i) for i in range(1, 11)]
  simulation = Simulation(network, cars, schedule_name=f"randomized_greedy_heuristic/schedule_10_RGH_k{i}.txt", k=i)
  simulation.start_sim(display=False)
# Out:
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_10_RGH_k2.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_10_RGH_k2.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_10_RGH_k3.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_10_RGH_k3.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_10_RGH_k4.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_10_RGH_k4.txt
# Starte Simulation...
# Simulation beendet.
# randomized_greedy_heuristic/schedule_10_RGH_k5.txt gespeichert unter: /home/anh/Documents/logisticsLab/data/randomized_greedy_heuristic/schedule_10_RGH_k5.txt
# Starte Simulation...
# Simulation beendet.
# ...

# %% [markdown]
# # Random Greedy Heuristic Multiple Runs (k = 5)

# %%
runs = 20
k = 5

# %% [markdown]
# ## 1 Car

# %%
dict = {}
for seed in range(runs):
  network = Network(machine_positions, transport_demand)
  car1 = Car(car_id=1, position=1)
  cars = [car1]
  simulation = Simulation(network, cars, k=k, seed=seed, save=False)
  simulation.start_sim(display=False)
  schedule = simulation.combine_schedules_preserve_order(save=False)
  dict[seed] = (simulation.total_empty_runs, schedule)

best_seed = min(dict, key=lambda x: dict[x][0])
best_empt, best_schedule = dict[best_seed]
best_schedule["emptyRuns"] = best_empt
save_schedule(best_schedule, f"randomized_greedy_heuristic_multistart/schedule_1_MRGH_k{k}_seed{best_seed}.txt")
# Out:
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.

# %% [markdown]
# ## 5 Cars

# %%
dict = {}
for seed in range(runs):
  network = Network(machine_positions, transport_demand)
  cars = [Car(car_id=i, position=i) for i in range(1, 6)]
  simulation = Simulation(network, cars, k=k, seed=seed, save=False)
  simulation.start_sim(display=False)
  schedule = simulation.combine_schedules_preserve_order(save=False)
  dict[seed] = (simulation.total_empty_runs, schedule)

best_seed = min(dict, key=lambda x: dict[x][0])
best_empt, best_schedule = dict[best_seed]
best_schedule["emptyRuns"] = best_empt
save_schedule(best_schedule, f"randomized_greedy_heuristic_multistart/schedule_5_MRGH_k{k}_seed{best_seed}.txt")
# Out:
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.

# %% [markdown]
# ## 10 Cars

# %%
dict = {}
for seed in range(runs):
  network = Network(machine_positions, transport_demand)
  cars = [Car(car_id=i, position=i) for i in range(1, 11)]
  simulation = Simulation(network, cars, k=k, seed=seed, save=False)
  simulation.start_sim(display=False)
  schedule = simulation.combine_schedules_preserve_order(save=False)
  dict[seed] = (simulation.total_empty_runs, schedule)

best_seed = min(dict, key=lambda x: dict[x][0])
best_empt, best_schedule = dict[best_seed]
best_schedule["emptyRuns"] = best_empt
save_schedule(best_schedule, f"randomized_greedy_heuristic_multistart/schedule_10_MRGH_k{k}_seed{best_seed}.txt")
# Out:
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.
# Starte Simulation...
# Simulation beendet.

# %% [markdown]
# # Plot and Save Results

# %% [markdown]
# These plots show all methods used for validation.

# %%
plot_validation_results(show=True, save=True)

# %% [markdown]
# This plot shows the best validation results for each scenario.

# %%
plot_best_validation_results(show=True, save=True)
