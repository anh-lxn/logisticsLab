# %%
from utils import read_txt_files, plot_dataframes_as_imgs
import pandas as pd


machine_positions, transport_demand = read_txt_files()
example_validation_result = pd.read_csv('../data/greedy_heuristic/schedule_5_GH_k1.txt', sep=';')

# %%
plot_dataframes_as_imgs(transport_demand.iloc[:10], '../docs/transport_demand.png', title="Transport Demand", save=True)
transport_demand
# Out:
#     start  dest  number
# 0       1     2       7
# 1       1     3       1
# 2       1     4       1
# 3       1     5       9
# 4       1     6       1
# ..    ...   ...     ...
# 85     10     5       5
# 86     10     6       8
# 87     10     7       5
# 88     10     8       3
# 89     10     9      10
#
# [90 rows x 3 columns]

# %%
plot_dataframes_as_imgs(example_validation_result.iloc[100:110], '../docs/schedule_example.png', title="Schedule Example", save=True)
example_validation_result
# Out:
#      VehicleId  Location  unload  load  emptyRuns
# 0            1         1       0     1         77
# 1            1         9       1     1         77
# 2            1         1       1     1         77
# 3            1         9       1     1         77
# 4            1         1       1     1         77
# ..         ...       ...     ...   ...        ...
# 514          5         5       1     0         77
# 515          5        10       0     1         77
# 516          5         4       1     0         77
# 517          5        10       0     1         77
# 518          5         4       1     0         77
#
# [519 rows x 5 columns]
